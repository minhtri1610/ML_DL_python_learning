# %% [markdown]
# Broadcasting -> lan truyền, cách là chúng ta thay đổi đồng loạt giá trị nhiều phần tử của mảng
#
# Numpy cho phép thực hiện tính toán giữa các mảng với số và các mảng khác chiều với nhau

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
numbers_1D = np.array([1, 2, 3])

# %%
numbers_1D + 3
# Out:
# array([4, 5, 6])

# %%
# Tương tự với phép trừ
numbers_1D + 3 - 10
# Out:
# array([-6, -5, -4])

# %%
numbers_2D = np.asarray([
    [4, 5, 6], 
    [7, 8, 9]
])

# %%
numbers_2D + 20
# Out:
# array([[24, 25, 26],
#        [27, 28, 29]])

# %%
numbers_2D * 20
# Out:
# array([[ 80, 100, 120],
#        [140, 160, 180]])
